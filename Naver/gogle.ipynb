# %%
from selenium import webdriver as wb
from bs4 import BeautifulSoup as bs
from selenium.webdriver.support.ui import Select
from selenium.webdriver import ActionChains
from selenium.webdriver.common.keys import Keys
import requests

# 이미지에 사용하는 라이브러리
import os
from urllib.request import urlretrieve # 이미지 경로를 파일로 저장하는 라이브러리
import time
import numpy as np
import pandas as pd

# %%
rest = pd.read_csv('./data/rest_name.csv', encoding='utf-8', index_col='rest_seq')
rest
# Out:
#              rest_name  rest_score  rest_tel  rest_addr  rest_attitude  \
# rest_seq
# 1             동원 게장 백반        4.16       NaN        NaN            NaN
# 2         광주 두꺼비 게장 백반        4.36       NaN        NaN            NaN
# 3                  민들레        4.43       NaN        NaN            NaN
# 4             백년미가 유촌점        4.19       NaN        NaN            NaN
# 5             백도 간장 게장        4.30       NaN        NaN            NaN
# ...                ...         ...       ...        ...            ...
# 105              매월한우촌        4.30       NaN        NaN            NaN
# 106         함평한우 육회비빔밥        4.80       NaN        NaN            NaN
# 107              한우육곰탕        4.20       NaN        NaN            NaN
# 108           금천한우정육식당        4.50       NaN        NaN            NaN
# 109         명품한우 육회비빔밥        4.70       NaN        NaN            NaN
#
#           rest_longtitude  rest_time  rest_comment food_name  \
# rest_seq
# ...

# %%
rest_name = rest['rest_name']
rest_name
# Out:
# rest_seq
# 1          동원 게장 백반
# 2      광주 두꺼비 게장 백반
# 3               민들레
# 4          백년미가 유촌점
# 5          백도 간장 게장
#            ...
# 105           매월한우촌
# 106      함평한우 육회비빔밥
# 107           한우육곰탕
# 108        금천한우정육식당
# 109      명품한우 육회비빔밥
# Name: rest_name, Length: 109, dtype: object

# %%
addr = []
tell = []
timeout = []

# %%
# 크롬 불러와서 사이트 접속하기

driver = wb.Chrome(executable_path='./chromedriver.exe')
driver.implicitly_wait(1)
# Out:
# C:\Users\USER\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
for i in rest_name :

    driver.get('https://www.google.com/maps/@35.1303264,126.9218576,15z?hl=ko')
    driver.implicitly_wait(10)

    search = driver.find_element_by_xpath('//*[@id="searchboxinput"]')
    search.send_keys(i)
    time.sleep(3)

    search.send_keys(Keys.ENTER)
    time.sleep(3)

    if 

    add = driver.find_element_by_xpath('//*[@id="pane"]/div/div[1]/div/div/div[9]/div[1]/button/div[1]/div[2]/div[1]').text
    timeout_one = driver.find_element_by_xpath('//*[@id="pane"]/div/div[1]/div/div/div[9]/div[2]/div[1]/div/div[1]/span[1]/jsl[2]/span[2]').text
    tell_one = driver.find_element_by_xpath('//*[@id="pane"]/div/div[1]/div/div/div[9]/div[2]/div[1]/div/div[1]/span[1]/jsl[2]/span[2]').text

    addr.append(add)
    tell.append(tell_one)
    timeout.append(timeout_one)

    time.sleep(5)
# Out:
# C:\Users\USER\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#
# C:\Users\USER\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:13: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   del sys.path[0]
# C:\Users\USER\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#
# C:\Users\USER\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:15: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   from ipykernel import kernelapp as app
# ---------------------------------------------------------------------------
# ...

# %%
addr
# Out:
# ['광주광역시 동구 지산동 111', '광주광역시 북구 신안동 중흥로 76']
