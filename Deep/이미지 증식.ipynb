# %%
import numpy as np
import os
from os import listdir
from os.path import isfile, join
from PIL import Image

# %%
np.random.seed(3)
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img

# %%
data_datagen = ImageDataGenerator(rescale=1./255)

data_datagen = ImageDataGenerator(rescale=1./255,
                                rotation_range=90, # 이미지 회줜
                                width_shift_range=0.2, # 수평방향 이동 범위내에서 임의로 원본이미지 이동
                                height_shift_range=0.2, # 수직방향 이동 범위내에서 임의로 원본 이미지 이동
                                shear_range=0.1, # 시계 반대방향으로 회줜
                                zoom_range=0.2, # 확대/축소
                                horizontal_flip=True, # 수평방향 뒤집기
                                fill_mode='nearest')

# %%
filename_in_dir = [] 

for root, dirs, files in os.walk('data/hanwuyukhoe_6'):
    for  fname in files:
        full_fname = os.path.join(root, fname)
        filename_in_dir.append(full_fname)

for file_image in filename_in_dir:
    print (file_image)
    img = load_img(file_image) 
    x = img_to_array(img)
    x = x.reshape((1,) + x.shape)

    i = 0

    for batch in data_datagen.flow(x,save_to_dir='data/hanwuyukhoe_copy_6', save_prefix='hanwuyukhoe', save_format='jpg'):
        i += 1
        if i > 8:
            break
# Out:
# data/hanwuyukhoe_6\523.jpg
# data/hanwuyukhoe_6\524.jpg
# data/hanwuyukhoe_6\526.jpg
# data/hanwuyukhoe_6\527.jpg
# data/hanwuyukhoe_6\529.jpg
# data/hanwuyukhoe_6\530.jpg
# data/hanwuyukhoe_6\531.jpg
# data/hanwuyukhoe_6\532.jpg
# data/hanwuyukhoe_6\533.jpg
# data/hanwuyukhoe_6\534.jpg
# data/hanwuyukhoe_6\한우 육회_0.jpg
# data/hanwuyukhoe_6\한우 육회_1.jpg
# data/hanwuyukhoe_6\한우 육회_107.jpg
# data/hanwuyukhoe_6\한우 육회_108.jpg
# data/hanwuyukhoe_6\한우 육회_11.jpg
# data/hanwuyukhoe_6\한우 육회_112.jpg
# data/hanwuyukhoe_6\한우 육회_115.jpg
# data/hanwuyukhoe_6\한우 육회_116.jpg
# data/hanwuyukhoe_6\한우 육회_12.jpg
# data/hanwuyukhoe_6\한우 육회_120.jpg
# data/hanwuyukhoe_6\한우 육회_122.jpg
# data/hanwuyukhoe_6\한우 육회_124.jpg
# data/hanwuyukhoe_6\한우 육회_125.jpg
# data/hanwuyukhoe_6\한우 육회_127.jpg
# data/hanwuyukhoe_6\한우 육회_129.jpg
# data/hanwuyukhoe_6\한우 육회_13.jpg
# data/hanwuyukhoe_6\한우 육회_130.jpg
# data/hanwuyukhoe_6\한우 육회_131.jpg
# data/hanwuyukhoe_6\한우 육회_134.jpg
# data/hanwuyukhoe_6\한우 육회_135.jpg
# data/hanwuyukhoe_6\한우 육회_136.jpg
# data/hanwuyukhoe_6\한우 육회_139.jpg
# data/hanwuyukhoe_6\한우 육회_142.jpg
# data/hanwuyukhoe_6\한우 육회_15.jpg
# data/hanwuyukhoe_6\한우 육회_150.jpg
# data/hanwuyukhoe_6\한우 육회_152.jpg
# data/hanwuyukhoe_6\한우 육회_153.jpg
# data/hanwuyukhoe_6\한우 육회_154.jpg
# data/hanwuyukhoe_6\한우 육회_155.jpg
# data/hanwuyukhoe_6\한우 육회_156.jpg
# data/hanwuyukhoe_6\한우 육회_159.jpg
